# %% [markdown]
# <a href="https://colab.research.google.com/github/ounon/BSA2020_Team_Google_Project_1/blob/master/ChatBotProject(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chatbot using Microsoft Azure
#
# ###Team google:
# Pau Gallardo - Sarah Büchner - Florian Emery - Ibrahim Ounon
#
# [Github Repository Team Google](https://github.com/ounon/BSA2020_Team_Google_Project_1)
#
# ### Project Video

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/a3HwDzyIfPg" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/a3HwDzyIfPg" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Abstract
# <dt align="justify">
#
# In this notebook we want show different means to create a chatbot. First of all, we have created a simple bot with the **Azure Web app bot serive**. Then we will show how to add the QnA functionality with the **QnA Maker** and language undestanding with the **LUIS** service. Finally, we have developped our **own Telegram weather bot** that we have integrated into Azure.
#
#
# ## What is a Chatbot?
#
# A bot is an **autonomous program that interacts with people or computer systems** in a predictable way. The logic behind a bot is designed and programmed by the bot creator, often with the help of tools like the Microsoft Bot Framework. Microsoft also has other AI services, included in Azure Cognitive Services, that can enhance the capabilities of your bots.
#
#
# ---
# </dt>
#
# ## **A) Azure Web App Bot**
# The purpose of this section is to familiarize you with Azure web app bot service. During the different steps of this tutorial, we have analyzed and explained each point of the implementation of this technologies.
#
# >*Note: Before starting the different steps, it is important to check that you are logged in with a different account than the university account. The university address should be used only for student registration. If this is not the case, you will see problems with the rights to manage services and resources.*
#
# ### Web app bot service - Azure
# Azure Bot Service allows you to manage in the same place different intelligent tools to build, test and deploy bots. Thanks to the full functionality of this service and the additional tools, it is possible to manage bots that use speech, understand natural language, etc...
#
# ####**1. Creation of the serive we app bot**
# - First log in on [Azure Portal](https://portal.azure.com)
# - Click on **creating a resource**
# - In Azure market place menu on the left, select **AI + Machine learning** then click on **Web app bot**
#
# A new tab will open with the possibility to create a web app bot service. To do this complete the form as follows:
#
# **Bot handle:** Unique identifier of our bot
#
# **Suscription:**  Suscription mode, in our case Azure for students
#
# **Resourge group:** Defines a group where all of your resources will be grouped together in order to facilitate management.
#
# **Location:** Where it will be stored
#
# **Pricing tier:** Category of pricing that determines number of messages. **IMPORTANT: select F0 (free)**
#
# **App name:** Name of your application
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/wab1.PNG?raw=true)
#
#
# For the rest of the steps, for the bot template section, we chose to select **Basic Bot in Node.js**. This choice is defined by two elements. First we are more comfortable with the javaScript code that we will see in more detail in the next steps. Secondly we chose to use a Basic template that predefines some features like language understanding and bot analysis, that we will use later.
#
# **LUIS App location:** Location of your App LUIS
#
# **LUIS Account:** Account on LUIS to link with this service*
#
# When all the parameters have been entered as described. Just click on the Create button. The service bot generation will take a few minutes and you will receive a notification when it is finished.
#
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/wab2.PNG?raw=true)
#
# When the generation is finished, click on **"Go to resource"** in the notification bar and you will arrive on your web app service.
#
# ####**2.Web app serive descritpion/management**
#
# In the management page of your app bot service, you have a menu on the left with different items to use for the management of your bot.
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/wab3.PNG?raw=true)
#
# ####**3.Test bot**
# In order to see if our bot is well functionning, click in the menu on **Test in Web chat** and you will see a welcome message displays "Welcome to bot Framewrok" it means that the bot is communicating correctly with the default settings.
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/testBot1.JPG?raw=true)
#
# Now you can communicate with the bot created. This default bot allows you to make flight reservations. You can see below an overview of the interaction with the bot to make a reservation.
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/testbot2.JPG?raw=true)
#
#
# ####**4.Web app code editor online**
#
# To manage the code and the construction of your bot, click on **Build** then go to **Open online code editor**. A new page will open with an online code editor allowing you to have a development environment.
#
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/code1.PNG?raw=true)
#
# In this menu, we will find all the source code of our bot service. It is possible to manage its content online, as we are doing it or to manage it locally by downloading the source code and using a microsoft framewok and a simulator.
#
# ### **B) Language Understanding (LUIS)**
#
# Language Understanding (LUIS) is a cloud-based API service that uses machine learning to the natural language text of a user's conversations to predict their overall meaning. A client application for LUIS is a conversation application that communicates with a user in natural language to accomplish a task.
#
# The bot created before contains the entire folders JSON that allow us to create and edit the intents and entities. For this, we have 2 choices:
# - Edit the code directly in the file
# - Import the file and edit it in LUIS
#
# For our project we will import the file to manage it in LUIS with the additional functionality that LUIS provides us. To do this, we need to copy the JSON file and extract it locally on our machine. Once this is done we will have to import it into LUIS and make a link between the webapp bot and LUIS. We will do these different steps in the following section **LUIS**.
#
# The LUIS service enables the user to build and customize on his own the language models, allowing any application or bot to understand different commands and act accordingly. In fact, LUIS is able to extract from a sentence (an order, or a question in our case) possible intents, its score (how much they match the sentence), as well as the different entities:
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/LUISpic.jpg?raw=true)
#
# ####Definition
# Here are some basic concepts to help you understand the use of this tool.
#
# -**Intent**
# The intents define the intentions of the users. What the user actually wants to do and meant with the sentence/question to the chatbot. Note that, if what the user says does not match exactly (spelling mistake, slightly different word) the Intent can still be identified as far as possible.
#
# -**Entities**
# Entities correspond to parameters of what the user says. These parameters can be a list, they can also be mandatory. You just have to check the right options.
# They are important words in a sentence/ request that will act like parameters within the intent function.
#
# For example: <br>
# Question by the user: "I would like to order a pizza Margherita". <br>
# For a chatbot of a Pizza restaurant/ delivery service the **intent** would be ORDER PIZZA and the **entity** MARGHERITA.
#
# ####**1.Import JSON file**
# To continue the development of our web serive app, we will import our JSON file that we extracted locally before. To do this, go to the LUIS web page:
#
# - www.luis.ai
#
# Be careful to log in with the **same account** you used for the portal Azure in order to manage the same resources between the two tools.
#
# When you are logged in go to "My apps" and click on import. Select the local JSON file and add an optional name then import your file as follows:
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/lui1.PNG?raw=true)
#
# Once your file is imported, click on the app that has just been created and you will arrive at the management page of your app.
#
# In this page it is possible to manage, build, train, test, publish and analyze through a Dashboard the performance of our API.
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/lui2.PNG?raw=true)
#
# ####**2.Train & Test**
#
# Training is the process of teaching your app to improve its understanding of the natural language. In order to check the correct operation of our default template file, just click on the train button that will browse the file. When the operation is completed, an "Up to date" information will appear on the screen.
#
# After this, you can test your app by clicking on the button in the main menu. For example by writing the sentence "I want to book a flight"! Our model contains intentions and entities concerning very basic operations such as booking and canceling a flight from one city to another with a defined date. Here is the example below:
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/testLui.PNG?raw=true)
#
# We can see on the screenshot that our request has a score of (0.922) this means that our app is certain at 92.2% of our intention. We will see it in depth later on different requests and the meaning of the model.
#
# ####**3.Entities & Intent Management**
# In the Build section we can see all the entities and intents that are defined by default in the model of our application. Here it is possible to edit and create new parameters:
#
# Customizing intents <br>
# We can add new intents, use prebuilt domain intents or delete existing. Add and change the utterances asssociated to each intent:
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/Custom_intent.png?raw=true)
#
# Customizing entities <br>
# We can create new entities, add prebuilt entities, add prebuilt domain entities or delete existing. For each entity we can add, change or delete synonmy and upload new entities as a json file. (roles and labeled utterances???)
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/Custome_entities.png?raw=true)
#
# Additional customization
# Also, we can improve the performance of our Bot by reviewing endpoint utterances, meaning that we will review the utterances (sentences intserted by user) for which LUIS is uncertain. If necessary we can for these utterances associate the correct intents and entities.
#
# We can also add so called phrase lists, which are sentences or words that belong togehter and should hence be treated similarly.
#
# To further improve the model is possible to specify template sentences (utterances) and indicate the position of specific entities in the sentence by clicking on "Patterns":
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/patterns.png?raw=true)
#
#
# ####**4.Publish app LUIS**
# Once our app is ready, it is possible to publish it in order to access it from another environment. To do this click on the "publish" button in the top right corner of the menu.
#
# - Define the production parameter and click on **Publish**
#
# When the application is published, a green message will appear on the screen with a link "refers to the list endpoint". Click on this link or go to manage application setting to get to the same page.
#
# In application settings you will find 3 important settings:
# - Application ID in application information
# - Primary Key in Azure Ressources
# - Region in Azure Rerrources also
#
# Take the information correctly in order to be able to fill it in the web app bot in azure and create the link.
#
#
#
# ####**5.Implementation**
# Now that our application has been well managed on LUIS and published, and that we have created the web app bot on Azure, we must at this stage manage the parameters in order to make the link between the two platform tools. To do this, go back to the Azure portal and in the left menu of your application click in "App service settings" on "configuration" as follows:
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/config.PNG?raw=true)
#
#
# In the configuration parameters it is necessary to set the 3 values that we found when we published the LUIS application:
#
# LuisApiHostName = **Region+**.api.cognitive.microsoft.com(ex:westeurope.api.cognitive.microsoft.com)
#
# LuisAPIkey = Primary Key
# LuisAppId = Application ID
#
# When all values have been set, click on the "Save" button. And here your web bot app configuration with LUIS is finished.
#
#
#
#
#
#
# ###Embed code in Web page
# In order to have a concrete idea and implementation of our bot we decided for our project to create a simple web page to implement our bot internally.
#
# First go to Azure in the right menu under "Bot Management" click on **Channel**. Then go to "Get bot embed codes", then **Click here to open the Web Chat configuration page**.
#
# Here is the page with the parameters of your link:
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/linkcodes.PNG?raw=true)
#
# In order to create a functional link, take out the secret key and embed code. When this is done you can embed it into your web page simply by implementing the line of code that has just been retrieved.
#
# Here a short HTML code that we created for the project:
#
# 	<html>
# 		<center>
# 		<head>
# 			<h1>Group project - Web app bot - BigScaleAnalytics </h1>
# 			<div>University reservation agency of lausanne</div>
# 		</head>
# 		<body>
# 			<iframe src='https://webchat.botframework.com/embed/flowab?s=HALpVLkKn7s.Eem8bY5PMZnrjzrqL6fY9NaYWRPBtROmXrxmi7sihSI'  style='min-width: 400px; min-height: 500px;'></iframe>
# 		</body>
# 	</center>
# 	</html>
#
#
# In the code above, we have implemented the embedded code in the body tag of the HTML page and in the link where it is mentioned **YOUR_SECRET_HERE**. We have to put the secret key that has been previously collected.
#
# Here the result on a web page:
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/pageHTML.PNG?raw=true)
#
# ###Comments & Sentiments analysis
# During the elaboration of our project, we realized how many possibilities and tools are available for the creation of an intelligent bot. We went through all the features and discovered some very advanced areas in bot development. In order to be able to generate and use all the functionalities, a pre-requisite in C or JS coding is essential to be able to code specific elements.
#
# ##**C) Self-coded Weather Chatbot**
#
# We decided to create a chatbot that gives the weather according to a city.
# To do this, we follow the same steps as before but this time we choose the **echo bot** model to create our bot from A to Z.
#
#
# After creating we have a bot that returns all user entries as in the image below
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/testbot3.JPG?raw=true)
#
# When we look at the code in the index.js file we get this
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/codebotecho.JPG?raw=true)
#
# We remove all the code to implement our bot. But before implementing the code of our bot, we have to create our LUIS model.
#
# ####**1.Creation of Luis model**
#
# We're logging on to Luis and we create our model named **WeatherBot**
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/newluisapp.JPG?raw=true)
#
# Now that our WeatherBot model is created we will create intents and entities.
# We will create a new intent called **GetWeather**
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/intentweather.JPG?raw=true)
#
# After creating intent, we will add utterance
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/intents.JPG?raw=true)
#
# Now we can create our entity. Our entity will be a city that we want know the weather. We name this entity **city**
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/entitescity.JPG?raw=true)
#
# After that we select whats words is the entities in your utterances by clicking the word
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/addcity.jpg?raw=true)
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/afterseclectionningcity.JPG?raw=true)
#
#
# You can see by default the itent prediction score is -1. A prediction score indicates how confident LUIS is in the prediction results of a user expression.
# A prediction score is between zero (0) and one (1). A highly confident LUIS score is very close to 1 and  a score of low confidence is very close 0.
#
# We are now going to train our model to recognize the user's intention according to the utterances. So we click on **Train** to start learning.
#
# We edit the utterance *it is running in Lausanne* and we train our model
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/updateutterance.JPG?raw=true)
#
# We can test a new utterance **"Is it sunny in Mexico?"** by clicking on **Test**
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/trainnewutterance.JPG?raw=true)
#
# Luis automatically detects our intention (GetWeather) which is to know the weather in Mexico. He identified Mexico City as the city entity.
#
# w we're testing an utterance that has nothing to do with the weather. We test *I eat Pizza*.
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/trainutterancePizza.JPG?raw=true)
#
# Luis categorized this utterance in GetWeather. He was wrong. But no problem we can change it by clicking on **edit** and then categorizing it as **None**. After that we click on **Train**.
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/trainpizza.JPG?raw=true)
#
# The coulter has increased to 0.930.
#
# You can add and test as much utterance as you want.
#
# Now we can implement the code after publishing.
#
#
# ####**2. Code implementation**

# %%
var request = require('request');
var restify = require('restify');
var builder = require('botbuilder');


// Connector
var connectorAppId = process.env.MicrosoftAppId;
var connectorAppPassword = process.env.MicrosoftAppPassword;

var inMemoryStorage = new builder.MemoryBotStorage();

var openWeatherMapKey = YOUR_OPENWETHERMAP_KEY;

// LUIS model
var luisModelUrl = 'https://westus.api.cognitive.microsoft.com/luis/v2.0/apps/YOUR_APPLICATION_ID?subscription-key=YOUR_APPLICATION_KEY';


// Create Restify Server
var server = restify.createServer();
server.listen(process.env.port || process.env.PORT || 3978, function () {
   console.log('%s listening to %s', server.name, server.url); 
});
  
// Create connector and bot
var connector = new builder.ChatConnector({
    appId: connectorAppId,
    appPassword: connectorAppPassword
});

var bot = new builder.UniversalBot(connector).set('storage', inMemoryStorage);;
server.post('/api/messages', connector.listen());

// Create LUIS recognizer 
var recognizer = new builder.LuisRecognizer(luisModelUrl);
var dialog = new builder.IntentDialog({ recognizers: [recognizer] });
bot.dialog('/', dialog);


// Adding dialog
dialog.matches('GetWeather', [
    function (session, args, next) {
        var city = builder.EntityRecognizer.findEntity(args.entities, 'city');
        session.send("looks like you want to know the weather")
        
        if (!city) {
            builder.Prompts.text(session, 'Which city ?');  
        } else {
            next({ response: city.entity });
        }
    },
    
    function (session, results) {
        if (results.response){
            openweathermap(results.response, function(success, previsions) {
                if (!success) return session.send('An error has occurred');
                                    
                session.send('It is ' + previsions.temperature + '°C in '
                             + previsions.city + ' with ' + previsions.description;);
            });
        }
       
    }
]);

dialog.onDefault(function (session) {
    session.send('I do not understand what you mean');
});


var openweathermap = function(city, callback){
	var url = 'http://api.openweathermap.org/data/2.5/weather?q=' + city + '&lang=en&units=metric&appid=' + openWeatherMapKey;
	
	request(url, function(err, response, body){
		try{		
			var result = JSON.parse(body);
			
			if (result.cod != 200) {
				callback(false);
			} else {
				var previsions = {
					temperature : Math.round(result.main.temp),
					city : result.name,
                    description: result.weather[0].description
				};
						
				callback(true, previsions);
			}
		} catch(e) {
			callback(false); 
		}
	});
}
# Out:
#   File "<ipython-input-1-3118de97c05d>", line 1
#     var request = require('request');
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# We need the modules botbuilder to create the bot, restify to create a server and request to call the API OpenWeatherMap that we use to get the information about the weather in a specific city.
#
# To use the openweathermap api, it is necessary to create an account on the site [https://openweathermap.org/](https://openweathermap.org/) so you will get a key that you will use to call the API.
#
# The variable *luisModelUrl* stores the URL of our model luis previously created.
#
# The *bot* variable is used to create our bot.
#
# The variable *recogniser* makes it possible to recognize the itents present in our model.
#
# Once our bot linked to luis we can create the dialogues we want. In our case if in a dialog the bot identifies the intention *GetWeather* it will return **"Look like you want to know the weather"** and if it doesn't detect a city it will ask the user with the question **"Which city?"**. After it is aware of the city it will return the current temperature in the desired city using the openweathermap API.
#
# However, if it doesn't recognize the GetWeather intention, it will return **"I do not understand what you mean"**.
#
# Now that we've implemented the bot we don't have to execute the code. This is done by clicking on *Run* in the vertical menu of the online editor of Azure.
#
#
# ####**3. Test in Web Chat**
#
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/testfinalbot.JPG?raw=true)
#
# It works!
#
# ####**4. Connecting to Telegram**
#
# After the creation of our bot we can connect it to several email applications like kik, telegram, facebook, skype etc...
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/channel.JPG?raw=true)
#
# To do that you have to click on channel and choose the application you would like to connect your bot to.
#
# We choose to connect our bot to Telegram. We click on Telegram and we follow the steps to connect the bot.
#
# You can play with our bot by adding it to your Telegram via this link [t.me/WeatheeeerBot](t.me/WeatheeeerBot).
#
#
# ![alt text](https://github.com/ounon/BSA2020_Team_Google_Project_1/blob/master/Pictures/TelegramChatBot.jpg?raw=true)
#
#
#
# ## **D) QnA Maker and Knowledge Base** - *(Coronavirus case)*
#
# **Question & Answer (QnA)**: QnA Maker is one of the AI services that can help a bot answer users' natural language questions by matching them with the best possible answers from an associated knowledge base.
#
# The simpliest way to feed a ChatBot using Microsoft Azure is through a **QnA knowledge base** commonly known as FAQ *(A file containing a bunch of potential questions that the user may query and their respective questions)*
#
# > In the following [link](https://docs.microsoft.com/en-us/learn/modules/build-a-faq-chat-bot-with-qna-maker-and-azure-bot-service/) is described the steps to create it.
#
# There are two options to populate the knowledge base: <br>(i) Using an existing source either copying the url or uploading a pdf/csv file. <br>(ii) Creating manually the FAQ file in the platform.
#
# ###What is QnA knowledge base?
# QnA Maker is a cloud-based API service that allows you to implement a question/answer knowledge base and interface as a chat. We need to import our data on the platform in order for the service to interface the chat.
# A knowledge base consists of sets of questions and answers provided by URLs and public files. Our bot will answer questions by matching them with the best possible answer from the knowledge base that we created. It is also possible to use the chit-chat file but we did not use it.
#
# ####**1.Create the Knowledge Base**
#
# *   Go to QnA Maker [website](https://www.qnamaker.ai/Home/MyServices)
# *   Sign in
# *   Create a knowledge base
#
# At this point just click on:  **Create a knowledge base**
#
# ![](https://github.com/SarahBuechner/TEST-REPO/blob/master/1.png?raw=true)
#
# By clicking on the link, a new window will open with the necessary steps to create the KB. This is how the page looks like:
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/2.png?raw=true)
#
# The **Step 1** is the creation of the QnA service in Azure. If a service has **already been created**, just go to the next step.
#
# By clicking on the button:
# You will be redirected to the azure portal in order to create the service.
#
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/3.png?raw=true)
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/4.png?raw=true)
#
# When creating the service, you only have to fill in the different fields. You have to define a name and a group as well as the subscription mode according to your account type.
#
# When the fields are well completed, just click on the **create button.**
#
# When the service has been created in Azure, go back to the QnA Maker page to continue with **step 2**. Refresh the content for the bot to bring up the information of the service you just created and complete the form as below with your information:
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/5.png?raw=true)
#
# **Step 3** is simply to name your knowledge base.
#
# **Step 4** is the most important one. It is the creation of the database that will allow to
# self-manage responses to users. We have several choices:
#
# * Refer to an online database *(url)*
# * Upload a local database *(pdf/docs file...)*
# * The possibility to activate a chit-chat which provides frequently used question-answers
#
# In our case we decided to use a world file containing questions and answers that we put together. In addition, we chose not to activate chit-chat for our bot. Here is the form of point 4:
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/6.png?raw=true)
#
# Finally, the **Step 5** is the creation of the knowledge base by clicking on the **Create your kb button**.
#
# After the creation of your knowledge base,a summary is displayed on the screen with all the pairs questions-answers. On this page it is possible to add/modify/delete content. Here is a preview of the page:
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/7.png?raw=true)
#
# ####**2.Test & Train your Chatbot**
# After creating the Knowledge Base and before publishing the Chatbot, it is also possible to test your bot by clicking on the top right **button Test**. After testing it, one may hit the **button Safe and train** this feature will improve the accuracy of the Chatbot.
#
# In our case we decided to create a knowledge base on the subject of coronavirus. In order to test its functioning, we asked the bot *What is coronavirus?* and it answered me correctly. See below:
#
# ![alt text](https://github.com/SarahBuechner/TEST-REPO/blob/master/8.png?raw=true)
#
# ####**3.Publish your Chatbot**
# After testing and training the Chatbot now you can puslish it. This will move the QnAs from the test step to the production step. Once this is done, the knowledge base will be available to the bot and can be used by it.
#
# ####**4.Integrate QnA with a bot**
# Once, the publishing of the knowledge base was successful we need to create a bot, that will use it to answer users' questions. For that we can just click on create a bot and fill in the different parameters. We will explain it in detail below. Once the bot has been created it will automatically be linked to the created knowledge base.
#
# ---
#
# ###Sources
# * [Microsoft Azure](https://azure.microsoft.com/en-us/)
# * [World Health Organization](https://www.who.int/emergencies/diseases/novel-coronavirus-2019)
# * [QnA Coronavirus dataset]()

# %% [markdown]
# ## Authors
# * **Pau Gallardo** - **Sarah Büchner** - **Florian Emery** - **Ibrahim Ounon**  -  [Github Repository Team Google](https://github.com/ounon/BSA2020_Team_Google_Project_1)
#
# ## Contributions
# Equal contribution by all participants.
